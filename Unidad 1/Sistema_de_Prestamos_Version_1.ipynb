# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelBadillo77/FundamentosProgramacion-/blob/main/Unidad%201/Sistema_de_Prestamos_Version_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ingenieria en sistemas Computacionales**
#
# ## **Fundamentos de  Programación**
#
# ## **Unidad 1**
#
# ### Sistema de Gestión de Préstamos y Reservaciones de Computadoras - Version 1
#
# Docente: **José Gabriel Rodriguez Rivas**
#
# Alumno: **Angel Gabriel Badillo Jacobo**

# %%
# ======================================
# SISTEMA DE PRESTAMOS
# Version 1 - Programacion basica y uso de listas
# =====================================

#Lista de alumnos activos en el sistema
alumnos = ("26040200","26040201","26040202","26040203","26040204")

# Cada valor en la lista de computadoras tiene su lista correspondiente con el
# aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                "PC-LC3-01", "PC-LC3-02", "PC-LC3-03"]

aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3"]

software = ["Phyton, VS Code", "Phyton, Java, VS Code", "AutoCAD, MATLAB",
            "Phyton, VS Code", "Phyton, Java, VS Code", "AutoCAD, MATLAB",
            "Phyton, VS Code", "Phyton, Java, VS Code", "AutoCAD, MATLAB", "Phyton, VS Code"]

estado = ["Disponible", "Prestada", "Reservada",
          "Disponible", "Prestada", "Reservada",
          "Disponible", "Prestada", "Reservada", "Mantenimiento"]

# MENU PRINCIPAL
# Usamos un ciclo while que se repetira indefinidamente hasta que el usuario
# tecle la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
  print("\n================================")
  print("SISTEMA DE PRESTAMOS")
  print("================================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar prestamo")
  print("4. Devolver computadora")
  print("5. Crear reservacion")
  print("6. Agregar computadora")
  print("7. Salir")
  print("================================")
  opcion = int(input("Seleccione una opcion: "))

  # 1. Consultar computadoras
  # si el usuario seleciono la opcion 1 se hace un ciclo (for) que recorre
  # toda lista de computadoras e imprime los valores de las demas listas
  if opcion == 1:
    print("\n--- COMPUTADORAS ---")
    for i in range(len(computadoras)):
        print("Aula:", aulas[i], "Software:",software[i],
              "Estado:", estado[i], "ID:", computadoras[i],
              "Software:",software[i], "Estado:", estado[i],)


  # 2. Buscar por software
  elif opcion == 2:
    programa = input("Ingrese el software que desea buscar: ")
    print("\n--- RESULTADOS ---")
    encontrado = False
    for i in range(len(computadoras)):
        # la funcion (lower) convierte a minuscula el texto, de esta forma
        # nos aseguramos que el texto a buscar y la informacion de las listas
        # este en minuscula y no tengamos problema de que no encuentra un programa
        # porque este escrito de forma diferente usando mayusculas y minusculas
        if programa.lower() in software[i].lower():
            print("ID:", computadoras[i])
            print("Aula:", aulas[i])
            print("Software:", software[i])
            print("Estado:", estado[i])
            encontrado = True

    if encontrado == False:
      print("No se encontraron computadoras con ese software")


  # 3. Solicitar préstamo
  elif opcion == 3:
      print("\n--- SOLICITAR PRÉSTAMO ---")
      num_control = input( "\nIngrese el número de control: " )
      encontrado1 = False
      # Verificar si existe el alumno en la lista o BD
      if num_control in alumnos:
          # Si existe, continuamos con el procedimiento
          encontrado1 = True
          id_computadora = input("Ingrese el ID de la computadora: " )
          encontrado2 = False
          for i in range(len(computadoras)):
              if computadoras[i] == id_computadora:
                  encontrado2 = True
                  if estados[i] == "Disponible":
                      estados[i] = "Prestada"
                      print("Préstamo registrado correctamente.")
                      print("Computadora:", computadoras[i])
                      print("Aula:", aulas[i])
                  else:
                      print("La computadora no está disponible.")
          if encontrado2 == False:
              print("La computadora no existe.")
      if encontrado1 == False:
          print("El alumno no existe.")

  elif opcion == 4:
      print("\n--- DEVOLVER COMPUTADORA ---")
      id_computadora = input("Ingrese el ID de la computadora: ")
      existe = False
      for i in range(len(computadoras)):
        if computadoras[i] == id_computadora:
          existe = True
          if estado[i] == "Prestada" or estado[i] == "Reservada":
            estado[i] = "Disponible"
            print("La computadora", id_computadora, "ya esta disponible")
            break
          else:
            print("La computadora", id_computadora, "no esta prestada/resevada")
      if existe == False:
          print("La computadora", id_computadora, "no existe")





  #6. Agregar computadora
  elif opcion == 6:
      print("\n--- AGREGAR COMPUTADORA ---")
      id_computadora = input("Ingrese el ID de la computadora: ")
      aula = input("Aula: ")
      programas = input("Software instalado:")
      computadoras.append(id_computadora)
      aulas.append(aula)
      software.append(programas)
      estado.append("Disponible")
      print("Computadora agregada correctamente.")
# Out:
# ================================
# SISTEMA DE PRESTAMOS
# ================================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora
# 7. Salir
# ================================
# Seleccione una opcion: 4
#
# --- DEVOLVER COMPUTADORA ---
# Ingrese el ID de la computadora: 548451
# La computadora 548451 no existe
#
# ================================
# SISTEMA DE PRESTAMOS
# ================================
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar prestamo
# 4. Devolver computadora
# 5. Crear reservacion
# 6. Agregar computadora
# 7. Salir
# ================================
# Seleccione una opcion: 9
